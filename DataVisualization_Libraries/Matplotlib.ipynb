# %% [markdown]
# # Matplotlib

# %% [markdown]
# **What is Matplotlib?**
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is a multi-platform library
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.
#
#
# ---
#
#
#
# **Where is the Matplotlib Codebase?**
#
# The source code for Matplotlib is located at this github repository https://github.com/matplotlib/matplotlib
#
#
#
# ---
#
# # **Installation of Matplotlib**
#
# If we have Python and PIP already installed on a system, then installation of Matplotlib is very easy.
#
# Install it using this command:
#
#
# `pip install matplotlib`
#
#
#
#
# If this command fails, then use a python distribution that already has Matplotlib installed,  like Anaconda, Spyder etc.
#
#
# ---

# %% [markdown]
# # **Import Matplotlib**
#
# Once Matplotlib is installed, import it in your applications by adding the import module statement:

# %%
import matplotlib         # importing matplotlib

# %% [markdown]
# Now Matplotlib is imported and ready to use:
#
# **Checking Matplotlib Version**
#
# The version string is stored under `__version__` attribute.

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.1.3

# %% [markdown]
# # **Pyplot**
#
# * ***matplotlib.pyplot*** is a collection of functions that make matplotlib work like MATLAB
# * ***pyplot*** functions are used to create a figure, create a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
import matplotlib.pyplot as plt          # importing pyplot as plt

# %% [markdown]
# Now the Pyplot package can be referred to as `plt`.

# %% [markdown]
# **Example**
#
# Draw a line in a diagram from position (0,0) to position (6,250):

# %%
# importing required libraries

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])         # created as array named 'xpoints' to specify x-coordinate values
ypoints = np.array([0, 250])       # to specipy y-coordinate values

plt.plot(xpoints, ypoints)         
plt.show()

# %% [markdown]
# **Matplotlib Plotting**
#
# Plotting x and y points:
#
# **`plot()` :** This function is used to draw points in a diagram. It plots y versus x as lines and/or markers
#
# > ***Note :*** By default, the `plot()` function draws a line from point to point.
#
# The function takes *Parameters :*
#
# - Parameter 1 is an array containing the points on the x-axis.
#
# - Parameter 2 is an array containing the points on the y-axis.
#
# **`show()` :** To display all *open* figures.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.
#
# **Example**
#
# Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
# to display a line drawn from (1, 3) to (8, 10)

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **Problem**
#
# Draw a line in a diagram from position (3, 5) to position (5, 15)

# %%
xpoints = np.array([3, 5])           # created an array of x-coordinates of both points i.e. 3 and 5
ypoints = np.array([5, 15])          # created an array of y-coordinates of both points i.e. 5 and 15

plt.plot(xpoints, ypoints)           # line created
plt.show()                           # to display

# %% [markdown]
# **Plotting Without Line**
#
# To plot only the markers, we can use shortcut string notation parameter 'o', which means 'rings'.
#
# **Example**
#
# Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# **Multiple Points**
#
# We can plot as many points as we like, but the only condition is they should have the same number of points in both axis.
#
#
# **Example**
#
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
# Plotting line with four points

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **Problem**
#
# Draw a line in a diagram from position (1, 2) to (5, 8) then to (9, 3) and finally to position (8, 10):

# %%
xpoints = np.array([1, 5, 9, 8])         # specified all x-coordinates to an array
ypoints = np.array([2, 8, 3, 10])        # specified all y-coordinates to an array

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **Default X-Points**
#
# > ***Note :*** If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3. Same as the length of y-points.
#
# **Example**
#
# Plotting without x-points:

# %%
# Here, taking only y-points and showing it takes by default values of x-points and then ploting

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# The x-points in the example above is [0, 1, 2, 3, 4, 5].

# %% [markdown]
# # **Markers**
#
# We can use the keyword argument **`marker`** to emphasize each point with a specified marker.
#
# > ***Note :*** By default if line is given, but no marker, the data will be a line without markers.
#
# **Example**
#
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')        # specified maker as 'o' to mark each point as circle
plt.show()

# %% [markdown]
# **Marker Reference**
#
# We can choose any of these markers:
#
# Marker 	Description
# 'o' 	Circle
# '*' 	Star
# '.' 	Point
# ',' 	Pixel
# 'x' 	X
# 'X' 	X (filled)
# '+' 	Plus
# 'P' 	Plus (filled)
# 's' 	Square
# 'D' 	Diamond
# 'd' 	Diamond (thin)
# 'p' 	Pentagon
# 'H' 	Hexagon
# 'h' 	Hexagon
# 'v' 	Triangle Down
# '^' 	Triangle Up
# '<' 	Triangle Left
# '>' 	Triangle Right
# '1' 	Tri Down
# '2' 	Tri Up
# '3' 	Tri Left
# '4' 	Tri Right
# '|' 	Vline
# '_' 	Hline

# %% [markdown]
# **Problem**
#
# Mark each point in the previous example with a star:

# %%
plt.plot(ypoints, marker = '*')                 # for star : maker = *
plt.show()

# %% [markdown]
# # **Format Strings fmt**
#
#
# We can use also use the shortcut string notation parameter to specify the marker. Shown bellow:
#
# This parameter is also called **`fmt`**, and is written with this syntax: *`marker|line|color`*
#
# **Example**
#
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')            # specified: makers = o (circle), line = : (dotted) and color = r (red)
plt.show()

# %% [markdown]
# The marker value can be anything from the Marker Reference above.
#
# The line value can be one of the following:
# Line Reference
#
# `Line Syntax` 	`Description`
#
#
# '-' 	Solid line
# ':' 	Dotted line
# '--' 	Dashed line
# '-.' 	Dashed/dotted line
#
#
# > ***Note :*** If we leave out the line value in the fmt parameter, no line will be plotted.
#
#
# The short color value can be one of the following:
#
# **Color Reference**
#
# `Color Syntax` 	`Description`
#
# 'r' 	Red
# 'g' 	Green
# 'b' 	Blue
# 'c' 	Cyan
# 'm' 	Magenta
# 'y' 	Yellow
# 'k' 	Black
# 'w' 	White
#
#
# **Marker Size Argument**
#
# **`markersize`** or **`ms` :** This keyword argument to set the size of the markers.

# %% [markdown]
# **Example**
#
# Set the size of the markers to 20:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)      # size of markers is set to 20 of type circle
plt.show()

# %% [markdown]
# **Marker Color Argument**
#
# **`markeredgecolor`** or **`mec` :** To set the color of the edge of the markers.
#
#
# ---
#
# **Example**
#
# Set the EDGE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')       # set edge of makers as red
plt.show()

# %% [markdown]
# **Marker Face Color Argument**
#
# **`markerfacecolor`** or **`mfc` :** To set the color inside the edge of the markers.
#
#
# ---
#
# **Example**
#
# Set the FACE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

# takes x-coordinates as 0, 1, 2, 3 by default

ypoints = np.array([3, 8, 1, 10])                           # specified y-coordinates.

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')          # marker of type circle, size 20 are color of marker is red
plt.show()

# %% [markdown]
# Use both the `mec` and `mfc` arguments to color of the entire marker:
#
#
#
# ---
#
# **Example**
#
# Set the color of both the edge and the face to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')              # here using both *mec* and *mfc* specified color red
plt.show()

# %% [markdown]
# **Problem**
#
# Mark each point with a green color in the previous example:

# %%
# to mark green color to each point...change the arrgument of mec and mfc to 'g' i.e. 'green'

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'g', mfc = 'g')                  
plt.show()

# %% [markdown]
# # **Line**
#
# **Line Style KeyWord Argument**
#
# **`linestyle`**, or **`ls` :** To change the style of the plotted line:
#
#
# **Example**
#
# Use a dotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')              # to plot dotted line
plt.show()

# %% [markdown]
# **Problem**
#
# Use a dashed line in the previous example.

# %%
# setting arrgument 'linestyle' as 'dashed' to print dashed line

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# **Shorter Syntax**
#
# The line style can be written in a shorter syntax:
#
# `linestyle` can be written as `ls`.
#
# `dotted` can be written as `:`.
#
# `dashed ` can be written as `--`.
#
#
# ---
#
#
# Example
#
# Shorter syntax:

# %%
# displaying graph with shorter syntax

plt.plot(ypoints, ls = ':')            # setting linestyle(ls) arrgument as dotted(:)

# %% [markdown]
# **Line Styles**
#
# We can choose any of these styles:
#
# `Style` 	`Or`
#
# 'solid' (default) 	'-'
# 'dotted' 	':'
# 'dashed' 	'--'
# 'dashdot' 	'-.'
# 'None' 	'' or ' '
#
#
# ---
#
# **Line Color Keyword Argument**
#
# **`color`** or **`c ` :** To set the color of the line.
#
#
#
# ---
# **Example**
#
# Set the line color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')                  # set color of line as red
plt.show()

# %% [markdown]
# **Problem**
#
# Plot with a green line:

# %%
plt.plot(ypoints, color = 'g')            # color = green to display green color line
plt.show()

# %% [markdown]
# **Line Width Keyword Argument**
#
# **`linewidth`** or **`lw` :** To change the width of the line. The value is a floating number, in points.
#
#
# ---
#
#
# **Example**
#
# Plot with a 20.5pt wide line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')               
plt.show()

# %% [markdown]
# **Multiple Lines**
#
# We can plot multiple lines in same space by adding more plt.plot() functions.
#
#
# ---
#
#
# **Example**
#
# Draw two lines by specifying a plt.plot() function for each line:

# %%
import matplotlib.pyplot as plt
import numpy as np

# plotting two line's in same space
# Here, x-cordinates are taken by default as 0, 1, 2, 3 for respective given y-coordinate

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# We can also plot many lines by adding the points for the x- and y-axis for each line in the same `plt.plot()` function.
#
#
# ---
# **Example**
#
# Draw two lines by specifiyng the x- and y-point values for both lines:

# %%
import matplotlib.pyplot as plt
import numpy as np

# plotting lines in same plane if both x and y coordinates are given

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)      # same as plt.plot(x1,y1) and plt.plot(x2, y2)
plt.show()

# %% [markdown]
# # **Subplots**
#
# **`subplot()` :** Add a subplot to the current figure. With the `subplots()` function We can draw multiple plots in one figure.
#
#
# ---
#
#
# **Example**
#
# Draw 2 plots:

# %% [markdown]
# > ***Note :*** Bellow we specified 1 row and 2 column so the second plot is printed beside rather then down. For down specify 2 row and 1 column.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)            # it has 1 row, 2 column and it is 1st plot
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)           # it has 1 row, 2 column and it is 2nd plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# **The subplots() Function**
#
# The `subplots()` function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.

# %%
 plt.subplot(1, 2, 1)       # the figure has 1 row, 2 columns, and this plot is the first plot.

# %%
 plt.subplot(1, 2, 2)         # the figure has 1 row, 2 columns, and this plot is the second plot.

# %% [markdown]
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:
#
#
# ---
#
# **Example**
#
# Draw 2 plots on top of each other:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)           # the figure has 2 row, 1 column and it is 1st plot
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)          # the figure has 2 row, 1 column and it is 2nd plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# We can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.
#
#
# ---
#
# **Example**
#
# Draw 6 plots:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

# specified that the ploting space has 2 rows and 3 columns

plt.subplot(2, 3, 1)            # 1st plot in regin
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)            # 2nd plot in regin
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)             # 3rd plot in regin
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)             # 4th plot in regin
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)              # 5th plot in regin
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)              # 6th plot in regin
plt.plot(x,y)

plt.show()

# %% [markdown]
# To plot `sin(x)` and `cos(x)` functions:
#
# **`np.sin(x)` :** Numpy function to plot sin(x).
#
# **`npcos(x)` :** Numpy function to plot cos(x).
#
# **`np.arange()` :** Numpy function has three arguments: start, stop, step.

# %% [markdown]
# **Problem**
#
# Draw 2 sublots of sin(x) and cos(x) in the domain (0,10).

# %%
x = np.arange(0,10, 0.1)       # start = 0, stop = 10 and step = 0.1  to print in domain 10
y = np.sin(x) 
z = np.cos(x)
plt.plot(x,y,x,z)              # same as plt.plot(x, y) and plt.plot(x, z)
plt.show()

# %% [markdown]
# # **Title**
#
# `title()` :  To add a title to each plot.
#
#
# ---
#
#
# **Example**
#
# 2 plots, with titles:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)       # 1 row, 2 column, 1st plot
plt.plot(x,y)
plt.title("SALES")         # give title = SALES
 
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)      # 1 row, 2 column, 2nd plot
plt.plot(x,y)
plt.title("INCOME")       # give title = INCOME

plt.show()

# %% [markdown]
# **Super Title**
#
# **`suptitle()` :** To add a title to the entire figure.
#
#
# ---
#
#
# **Example**
#
# Add a title for the entire figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")         # given title to entire plot
plt.show()

# %% [markdown]
# # **Scatter**
#
# With Pyplot, we can use the `scatter() `function to draw a scatter plot.
#
# **`scatter()` :** A scatter plot of y vs. x with varying marker size and/or color. The `scatter()` function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis.
#
#
# ---
#
# **Example**
#
# A simple scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# created two arrays x and y of same length

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)      # creating scatter plot
plt.show()

# %% [markdown]
# The *observation* in the example above is the result of 13 cars passing by.
#
# The *X-axis* shows *how old the car is.*
#
# The *Y-axis* shows the *speed of the car when it passes.*
#
# *Relationships between the observations :*  It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %% [markdown]
# **Compare Plots**
#
# We observe that there may be the relationship between speed and age, here then trying to identify the changes in observation if we increase the number of days.
#
#
# ---
#
#
# **Example**
#
# Draw two plots on the same figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

# day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

# day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# > ***Note :*** By default two plots are plotted with two different colors 'blue' and 'orange'.
#
#
# *Comparing new Observation :* The newer the car, the faster it drives i.e. same conclusion.
#
#
# **Colors Argument**
#
# **`color`** or **`c` :** To set color for each scatter plot.
#
#
# ---
#
#
# **Example**
#
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')                           # setting color as hotpink

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')                           # setting green color

plt.show()

# %% [markdown]
# **Color Each Dot**
#
# We can also apply different colors to each dot by using an *array of colors* as value for the c argument.
#
# > ***Note :*** To apply this feature use *`c`* argument `not color.`
#
#
# ---
#
# **Example**
#
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])       # specifying different color to each dot

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# # **ColorMap**
#
# The Matplotlib module has a number of in-built available colormaps via `matplotlib.cm.get_cmap`.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# Here is an example of a colormap:
#
# ![Screenshot from 2021-01-21 12-46-48.png](data:image/png;base64,...)

# %% [markdown]
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, and up to 100, which is a yellow color.
#
# The idea behind choosing a good colormap is to find a good representation in 3D colorspace for your data set.
#
#
# ---
#
#
# **How to Use the ColorMap**
#
# Specify the colormap with the keyword argument `cmap` with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
#
# > ***Note :*** Matplotlib will give you `viridis` as a default colormaps.
#
# Other examples of colormaps in Matplotlib are Diverging, Cyclic, Qualitative, and Misc colormaps. We can also own are own colormaps.
#
# ---
#
#
# **Example**
#
# Create a color array, and specify a colormap in the scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')          

plt.show()

# %% [markdown]
# **`plt.colorbar()` :** To include the colormap in the drawing.
#
#
# ---
#
#
# **Example**
#
# Include the actual colormap:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()            # to display colormap

plt.show()

# %% [markdown]
# **Size**
#
# We can change the size of the dots with the **`s`** argument.
#
#
# > ***Note :*** Array of sizes should have same length as array for x and y axis.
#
#
# ---
#
#
# **Example**
#
# Set your own size for the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])           # creating array of sizes...same length as array of x and y axis

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# **Alpha Argument**
#
# **`alpha` :** To adjust the transparency of the dots.
#
# > ***Note :*** Array for sizes has the same length as the arrays for the x- and y-axis.
#
#
# ---
#
#
# **Example**
#
# Set your own size for the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)            # transparency = 50%
 
plt.show()

# %% [markdown]
# **Combine Color Size and Alpha**
#
# We can combine a colormap with different sizes on the dots. This is best visualized if the dots are transparent:
#
#
# ---
#
#
# **Example**
#
# Create random arrays with 100 values for x-points, y-points, colors and sizes:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))             # random x-coordiantes
y = np.random.randint(100, size=(100))             # random y-coordinates
colors = np.random.randint(100, size=(100))        # random colors
sizes = 10 * np.random.randint(100, size=(100))    # random sizes

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')     

plt.colorbar()                                     # plot colormap

plt.show()

# %% [markdown]
# # **Bars**
#
# **`bar()` :**  To draw bar graphs.
#
# - The bars are positioned at x with the given alignment.
# - Their dimensions are given by width and height.
# - The vertical baseline is bottom (default 0).
# - Each of x, height, width, and bottom may either be a scalar applying to all bars, or it may be a sequence of length N providing a separate value for each bar.
# - The `bar()` function takes arguments that describes the layout of the bars.
#
#
#
# ---
#
#
# Example
#
# Draw 4 bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ---
#
#
# **Example**

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **Horizontal Bars**
#
# If we want the bars to be displayed horizontally instead of vertically, use the `barh()` function:
#
#
# ---
#
#
# **Example**
#
# Draw 4 horizontal bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)           # to display horizontal bars
plt.show()

# %% [markdown]
# **Bar Color**
#
# The `bar()` and `barh()` takes the keyword argument color to set the color of the bars:
#
#
# ---
#
#
# **Example**
#
# Draw 4 red bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")             # keyword argument 'color = red'....for red color bars
plt.show()

# %% [markdown]
# **Bar Width**
#
# The `bar()` takes the keyword argument width to set the width of the bars.
#
#
# ---
#
#
# **Example**
#
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)             # width of the bars is 0.1 specified by 'width' argument
plt.show()

# %% [markdown]
# > ***Note :*** The default width value is 0.8
#
# > ***Note :*** For horizontal bars, use height instead of width.
#
# **Bar Height**
#
# The `barh()` takes the keyword argument height to set the height of the bars.
#
#
# ---
#
#
# **Example**
#
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)             # to set height of horizontal bars set height = 0.1 in brah() function
plt.show()

# %% [markdown]
# # **Histograms**
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# Example: We ask for the height of 250 people, you might end up with a histogram like this:
#
# ![img_matplotlib_histogram1.png](data:image/png;base64,...)
#
#
#
# We can read from the histogram that there are approximately:
#
# - 2 people from 140 to 145cm
# - 5 people from 145 to 150cm
# - 15 people from 151 to 156cm
# - 31 people from 157 to 162cm
# - 46 people from 163 to 168cm
# - 53 people from 168 to 173cm
# - 45 people from 173 to 178cm
# - 28 people from 179 to 184cm
# - 21 people from 185 to 190cm
# - 4 people from 190 to 195cm

# %% [markdown]
# **Create Histogram**
#
# In Matplotlib, we use the `hist()` function to create histograms.
#
# The `hist()` function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.
#
#
# ---
#
#
# **Example**
#
# A Normal Data Distribution by NumPy:

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [179.36172161 177.99949591 164.20233434 165.42549737 160.37557739
#  185.69057674 168.97597097 169.11278568 174.74586258 181.06390111
#  147.6345619  173.29714187 170.54781134 166.14616762 157.69862602
#  156.96599949 163.88095366 166.01765123 168.68373288 159.11697209
#  178.71376591 173.38536039 151.78353198 172.66053609 155.18387868
#  171.08847285 167.0911019  176.37495    178.01175503 180.9323808
#  189.85888283 168.51810476 169.64149846 182.62914067 157.27285143
#  154.97090907 166.50591675 173.87293493 173.98742635 174.26099203
#  164.81481734 175.12367387 175.5996859  181.1461128  183.73040769
#  170.50652931 167.99435599 162.75802588 171.95746894 151.16420526
#  166.75547492 164.48484132 154.37587767 167.26899493 168.89925061
#  167.21686474 173.55891626 173.75393607 166.61498746 178.41051706
#  166.76285065 173.01295113 177.62721625 168.46600986 185.03209538
#  155.92651631 168.1037443  167.07585271 155.7506387  186.04836468
# ...

# %% [markdown]
# The `hist()` function will read the array and produce a histogram.
#
#
# ---
#
#
# **Example**
#
# A simple histogram:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)             # randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.

plt.hist(x)
plt.show()

# %% [markdown]
# # **Pie Charts**
#
# **`pie()` :** To draw pie charts.
#
#
# ---
#
#
# **Example**
#
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)          # to plot pie chart
plt.show()

# %% [markdown]
# As you we see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# > ***Note :*** By default the plotting of the first wedge starts from the x-axis and move counterclockwise.

# %% [markdown]
# > ***Note :*** The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: `x/sum(x)`

# %% [markdown]
# **Labels**
#
# **`label` :** To add labels to the pie chart.
#
# > ***Note :*** The label parameter must be an array with one label for each wedge.
#
#
# ---
#
#
# **Example**
#
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]          # labels to each edge

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# **Start Angle**
#
# **`startangle` :** To change the start angle of pie chart by default it is x-axis.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0.

# %% [markdown]
# **Example**
#
# Start the first wedge at 90 degrees:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)      # we rotated by 90 degree...therefore see Apples- 1st lable start with y-axis
plt.show()

# %% [markdown]
# **Explode**
#
# **`explode` :** Use this parameter to explode one wedges stand out.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed.
#
#
# ---
#
#
# **Example**
#
# Pull the "Apples" wedge 0.2 from the center of the pie:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]                        # apples wedge 0.2 units away from center ...rest joint to center

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# **Shadow**
#
# Add a shadow to the pie chart by setting the `shadows` parameter to `True`.
#
#
# ---
#
#
# **Example**
#
# Add a shadow:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# **Colors**
#
# **`colors` :** To set the color of each wedge.
#
# The colors parameter, if specified, must be an array with one value for each wedge.
#
#
# ---
#
#
# **Example**
#
# Specify a new color for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]             # giving colors to wedges...same as the size of x and y-axis

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# We can use Hexadecimal color values, any of the 140 supported color names, or one of these shortcuts:
#
#
# * 'r' - Red;
# * 'g' - Green;
# * 'b' - Blue;
# * 'c' - Cyan;
# * 'm' - Magenta;
# * 'y' - Yellow;
# * 'k' - Black;
# * 'w' - White;

# %% [markdown]
# **Legend**
#
# **`legend()` :** To add a list of explanation for each wedge.
#
#
# ---
#
#
# **Example**
#
# Add a legend:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)           
plt.legend()               # ploted labels to ass a list of details for each wedge
plt.show()

# %% [markdown]
# **Legend With Header**
#
# To add a header to the legend, add the `title` parameter to the `legend` function.
#
#
# ---
#
#
# **Example**
#
# Add a legend with a header:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")          # added title parameter to legend() to display title to legends
plt.show()
